# %%
import pandas as pd
import numpy as np
import pickle
import urllib.request
import dateutil.parser
import dateutil.rrule
import datetime
from IPython.display import display, HTML

# %% [markdown]
# ## Summary
#
# These tables compare the footfall data at two strategic locations in Newcastle, one counter spanning the full width of Northumberland St, and a second on the corner of Blackett St and John Dobson St used as a thoroughfare to the shopping district.
#
# For each day and each direction, the following percentages are given with respect to the average pedestrians per hour:
#  * Change since the day before
#  * Change since the same weekday last week
#  * Change compared to the median for the same weekday calculated over the last year
#
# Statistics are provided for the morning peak, afternoon peak, inter-peak period (essentially daytime outside of peak hours), and night. As footfall is unlikely to be evenly distributed across these periods, the statistics for the current period will be volatile while data is still coming in.

# %%
# Used across most of the plots for people flows
dateToday = datetime.datetime.combine(datetime.date.today(), datetime.datetime.min.time())
peopleCountInterval = 900
peopleCountFrames = pickle.load(open('../cache/recent-pedestrian-flows-pd.pkl', 'rb'))

# TODO: Make this reflect the last entry in the frame, not the time now
print('Last data obtained %s' 
    % (np.max(list(map(lambda f: np.max(f.index), peopleCountFrames.values()))).strftime('%d %B %Y %H:%M')))
# Out:
# Last data obtained 19 March 2020 09:15

# %%
# Ignore non-numeric columns in the dataframe
plottableTypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
perMinuteFactor = (peopleCountInterval / 60)

# %%
sensorsToSummarise = {
    'Northumberland St near TK Maxx': 'Newcastle: City centre shopping district (Northumberland St near TK Maxx)',
    'Pavement (south side) corner John Dobson St and Blackett St': 'Newcastle: City centre edge of shopping district (corner of Blackett St and John Dobson St)'
}

def classifyTime(t):
    hour = int(t.strftime('%H'))
    if hour < 7:
        return 'Night (19:00 - 07:00)'
    elif hour < 10:
        return 'Morning peak (07:00 - 10:00)'
    elif hour < 16:
        return 'Inter-peak (10:00 - 16:00)'
    elif hour < 19:
        return 'Evening peak (16:00 - 19:00)'
    else:
        return 'Night (19:00 - 07:00)'

periodDurations = {
    'Morning peak (07:00 - 10:00)': 3,   # 7 - 10
    'Inter-peak (10:00 - 16:00)': 6,     # 10 - 16
    'Evening peak (16:00 - 19:00)': 3,   # 16 - 19
    'Night (19:00 - 07:00)': 12
}

allPeriods = list(periodDurations.keys())

for sensorName in sensorsToSummarise.keys():
    dateIndex = []
    directionIndex = []
    summaryData = []
    
    dfSensor = peopleCountFrames[sensorName].copy()
    dfSensor.insert(0, 'Date', dfSensor.index.to_series().apply(lambda t: t.date()))
    dfSensor.insert(0, 'Day of week', dfSensor.index.to_series().apply(lambda t: t.strftime('%A')))
    dfSensor.insert(1, 'Time of day', dfSensor.index.to_series().apply(lambda t: t.strftime('%H:%M:%S')))
    dfSensor.insert(1, 'Period', dfSensor.index.to_series().apply(classifyTime))

    dfDailyPeriodTotals = dfSensor.groupby(['Date', 'Day of week', 'Period'], as_index=False).sum()
    dfAveragePeriodTotals = dfDailyPeriodTotals.groupby(['Day of week', 'Period'], as_index=False).median()
    
    for d in range(9, -1, -1):
        sensorDate = dateToday - pd.Timedelta(days=d)
        dateIndex.extend(np.repeat(sensorDate.strftime('%A %d %B'), 2))

        directionColumns = dfSensor.select_dtypes(plottableTypes).columns
        directionIndex.extend(directionColumns)
                         
        dfSensorOnDate = dfSensor.loc \
            [(sensorDate <= dfSensor.index) &
            (dfSensor.index < sensorDate + pd.Timedelta(hours=24))] \
            .copy() \
            .groupby(['Period']) \
            .agg(['sum', 'count']) \
            [directionColumns]
        dfSensorLastWeek = dfSensor.loc \
            [(sensorDate - pd.Timedelta(days=7) <= dfSensor.index) &
            (dfSensor.index < sensorDate - pd.Timedelta(days=7) + pd.Timedelta(hours=24))] \
            .copy() \
            .groupby(['Period']) \
            .agg(['sum', 'count']) \
            [directionColumns]
        dfSensorYesterday = dfSensor.loc \
            [(sensorDate - pd.Timedelta(days=1) <= dfSensor.index) &
            (dfSensor.index < sensorDate - pd.Timedelta(days=1) + pd.Timedelta(hours=24))] \
            .copy() \
            .groupby(['Period']) \
            .agg(['sum', 'count']) \
            [directionColumns]

        dfSensorAverageDayOfWeek = dfAveragePeriodTotals[dfAveragePeriodTotals['Day of week'] == sensorDate.strftime('%A')]

        for direction in directionColumns:
            summaryRow = []
            for period in allPeriods:
                periodStats = dfSensorOnDate[dfSensorOnDate.index == period][direction]
                if not periodStats['sum'].empty:

                    # Convert to an hourly value
                    periodTotal = periodStats['sum'].values[0]
                    periodHourly = periodTotal / periodStats['count'].values[0] * (3600 / peopleCountInterval)

                    # Change on yesterday
                    yesterdayHourly = dfSensorYesterday[dfSensorYesterday.index == period][direction]
                    yesterdayHourly = (yesterdayHourly['sum'].values[0] / yesterdayHourly['count'].values[0]) * (3600 / peopleCountInterval)
                    yesterdayChange = (periodHourly - yesterdayHourly) / yesterdayHourly

                    # Change on last week
                    lastWeekHourly = dfSensorLastWeek[dfSensorLastWeek.index == period][direction]
                    lastWeekHourly = (lastWeekHourly['sum'].values[0] / lastWeekHourly['count'].values[0]) * (3600 / peopleCountInterval)
                    lastWeekChange = (periodHourly - lastWeekHourly) / lastWeekHourly

                    # Change on normal profile
                    profileHourly = dfSensorAverageDayOfWeek[dfSensorAverageDayOfWeek['Period'] == period][direction]
                    profileHourly = profileHourly.values[0] / periodDurations[period]
                    profileChange = (periodHourly - profileHourly) / profileHourly

                    summaryRow.extend([
                        periodHourly, # Total
                        yesterdayChange, # Change on yesterday
                        lastWeekChange, # Change on last week
                        profileChange, # Change on average
                    ])
                else:
                    summaryRow.extend(np.repeat(0.0, 4))     
            summaryData.append(summaryRow)

    rowIndex = pd.MultiIndex.from_arrays([
            dateIndex,
            directionIndex
        ],
        names=['Date', 'Direction']
    )

    formattersSummary = {}
    colPeriods = []
    colStats = []
    for period in allPeriods:
        formattersSummary[(period, 'Hourly average flow')] = '{:,.0f}'
        formattersSummary[(period, 'Change from day before (%)')] = '{:+,.0%}'
        formattersSummary[(period, 'Change from week before (%)')] = '{:+,.0%}'
        formattersSummary[(period, 'Change from annual average (%)')] = '{:+,.0%}'
        colPeriods.extend(np.repeat(period, 4))
        colStats.extend([
            'Hourly average flow',
            'Change from day before (%)',
            'Change from week before (%)',
            'Change from annual average (%)'
        ])

    colIndex = pd.MultiIndex.from_arrays(
        [colPeriods, colStats],
        names=['Period', 'Statistic']
    )

    dfSummary = pd.DataFrame(summaryData, columns=colIndex, index=rowIndex)
    dfSummaryStyler = dfSummary.style \
        .format(formattersSummary) \
        .set_caption(sensorsToSummarise[sensorName]) \
        .set_table_styles(
            [dict(selector="th",props=[('text-align', 'center')]),
                dict(selector="tr:nth-child(2) th.col_heading",
                     props=[('vertical-align', 'bottom'),
                            ('writing-mode', 'vertical-rl'),
                            ]),
             dict(selector="caption",props=[('font-weight', 'bold'), ('font-size', '120%')])
            ]
        )

    periodBarColours = {
        'Morning peak (07:00 - 10:00)': '#FFA07A50',
        'Inter-peak (10:00 - 16:00)': '#EE1F5F50',
        'Evening peak (16:00 - 19:00)': '#FFA07A50',
        'Night (19:00 - 07:00)': '#A0FF7A50'
    }

    for period in allPeriods:
        dfSummaryStyler.background_gradient(
            subset=[(period, 'Change from annual average (%)')],
            vmin=-1.0,
            vmax=1.0,
            cmap='PiYG'
        )
        dfSummaryStyler.bar(subset=[(period, 'Hourly average flow')], color=periodBarColours[period], vmin=0)

    display(HTML(dfSummaryStyler._repr_html_()))
# Out:
# <style  type="text/css" >
#     #T_bdbd9cc2_69cf_11ea_b787_0242ac110002 th {
#           text-align: center;
#     }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002 tr:nth-child(2) th.col_heading {
#           vertical-align: bottom;
#           writing-mode: vertical-rl;
#     }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002 caption {
#           font-weight: bold;
#           font-size: 120%;
#     }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 100.0%, transparent 100.0%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row0_col3 {
#             background-color:  #fbe9f2;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 67.5%, transparent 67.5%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row0_col7 {
#             background-color:  #fde2f0;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 68.7%, transparent 68.7%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row0_col11 {
#             background-color:  #e7f5d3;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row0_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 51.3%, transparent 51.3%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row0_col15 {
#             background-color:  #f3f6ed;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 59.5%, transparent 59.5%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row1_col3 {
#             background-color:  #fce5f1;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 70.0%, transparent 70.0%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row1_col7 {
#             background-color:  #fddeee;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 91.5%, transparent 91.5%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row1_col11 {
#             background-color:  #eff6e5;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row1_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 52.0%, transparent 52.0%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row1_col15 {
#             background-color:  #e6f5d0;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 93.0%, transparent 93.0%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row2_col3 {
#             background-color:  #f9f1f5;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 67.4%, transparent 67.4%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row2_col7 {
#             background-color:  #fde2f0;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 46.4%, transparent 46.4%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row2_col11 {
#             background-color:  #fbd9ec;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row2_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 30.3%, transparent 30.3%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row2_col15 {
#             background-color:  #f3bcdd;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 56.2%, transparent 56.2%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row3_col3 {
#             background-color:  #f9eef4;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 69.0%, transparent 69.0%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row3_col7 {
#             background-color:  #fbd8eb;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row3_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 63.0%, transparent 63.0%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row3_col11 {
#             background-color:  #f8cee6;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row3_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 29.7%, transparent 29.7%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row3_col15 {
#             background-color:  #f6c7e3;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 99.1%, transparent 99.1%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row4_col3 {
#             background-color:  #faecf3;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 66.2%, transparent 66.2%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row4_col7 {
#             background-color:  #fad4e9;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row4_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 62.7%, transparent 62.7%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row4_col11 {
#             background-color:  #f8f3f6;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row4_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 40.1%, transparent 40.1%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row4_col15 {
#             background-color:  #fbd9ec;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 63.9%, transparent 63.9%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row5_col3 {
#             background-color:  #f9eef4;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 68.2%, transparent 68.2%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row5_col7 {
#             background-color:  #f8cee6;
#             color:  #000000;
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row5_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 78.5%, transparent 78.5%);
#         }    #T_bdbd9cc2_69cf_11ea_b787_0242ac110002row5_col11 {
# <style  type="text/css" >
#     #T_bf4a0990_69cf_11ea_b787_0242ac110002 th {
#           text-align: center;
#     }    #T_bf4a0990_69cf_11ea_b787_0242ac110002 tr:nth-child(2) th.col_heading {
#           vertical-align: bottom;
#           writing-mode: vertical-rl;
#     }    #T_bf4a0990_69cf_11ea_b787_0242ac110002 caption {
#           font-weight: bold;
#           font-size: 120%;
#     }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 100.0%, transparent 100.0%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row0_col3 {
#             background-color:  #fbe9f2;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row0_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 82.0%, transparent 82.0%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row0_col7 {
#             background-color:  #faecf3;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row0_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 64.7%, transparent 64.7%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row0_col11 {
#             background-color:  #f3f7ef;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row0_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 45.3%, transparent 45.3%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row0_col15 {
#             background-color:  #faeaf2;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 78.1%, transparent 78.1%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row1_col3 {
#             background-color:  #f5f7f3;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row1_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 80.2%, transparent 80.2%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row1_col7 {
#             background-color:  #f8f2f5;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row1_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 77.8%, transparent 77.8%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row1_col11 {
#             background-color:  #eef6e2;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row1_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 49.5%, transparent 49.5%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row1_col15 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 93.5%, transparent 93.5%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row2_col3 {
#             background-color:  #fbe9f2;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row2_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 81.5%, transparent 81.5%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row2_col7 {
#             background-color:  #fbe6f1;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row2_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 44.5%, transparent 44.5%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row2_col11 {
#             background-color:  #f7cbe4;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row2_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 23.1%, transparent 23.1%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row2_col15 {
#             background-color:  #df79b0;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 73.9%, transparent 73.9%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row3_col3 {
#             background-color:  #f7f7f7;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row3_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 79.6%, transparent 79.6%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row3_col7 {
#             background-color:  #faecf3;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row3_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 50.9%, transparent 50.9%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row3_col11 {
#             background-color:  #f5c6e2;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row3_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 23.2%, transparent 23.2%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row3_col15 {
#             background-color:  #e07eb3;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 84.3%, transparent 84.3%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row4_col3 {
#             background-color:  #fbd8eb;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row4_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 56.7%, transparent 56.7%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row4_col7 {
#             background-color:  #f1b7da;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row4_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 64.6%, transparent 64.6%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row4_col11 {
#             background-color:  #f9f1f5;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row4_col12 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#A0FF7A50 33.8%, transparent 33.8%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row4_col15 {
#             background-color:  #eba1cb;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 66.6%, transparent 66.6%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row5_col3 {
#             background-color:  #fbe8f2;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row5_col4 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#EE1F5F50 53.2%, transparent 53.2%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row5_col7 {
#             background-color:  #f1b5d9;
#             color:  #000000;
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row5_col8 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#FFA07A50 74.7%, transparent 74.7%);
#         }    #T_bf4a0990_69cf_11ea_b787_0242ac110002row5_col11 {
