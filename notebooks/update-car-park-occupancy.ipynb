# %%
import pandas as pd
import numpy as np
import json
import math
import urllib.request
import dateutil.parser
import dateutil.rrule
import datetime

# %%
# Used across all of the plots
dateToday = datetime.datetime.combine(datetime.date.today(), datetime.datetime.min.time())
baselineEnd = datetime.datetime.strptime('2020-03-13T23:59:59Z', '%Y-%m-%dT%H:%M:%SZ')

resampleFrequency = 900

# %% [markdown]
# # Car park occupancy across Tyne and Wear
#
# The data represents the car parks with ANPR at the entry and exit, with data collected through Tyne and Wear UTMC. This is not all car parks.

# %%
print('Last updated %s' % (datetime.datetime.now().strftime('%d %B %Y %H:%M')))

carParkRequestBase = 'https://api.newcastle.urbanobservatory.ac.uk/api/v2/sensors/entity'

# Fetch a list of all the car parks...
carParkTimeseriesIRIs = {}
carParkMetadata = {}
carParkRequestPage = 1
carParkResponse = None

while carParkResponse is None or len(carParkResponse) > 1:
    carParkResponse = json.loads(
        urllib.request.urlopen(
            '%s?metric="Occupied%%20spaces"&page=%u' % (carParkRequestBase, carParkRequestPage)
        ).read().decode('utf-8')
    )['items']

    carParkRequestPage = carParkRequestPage + 1

    for carPark in carParkResponse:
        for feed in carPark['feed']:
            for timeseries in feed['timeseries']:
                for link in timeseries['links']:
                    if (link['rel'] == 'archives.friendly' and \
                        'latest' in timeseries):
                        carParkTimeseriesIRIs[carPark['meta']['name']] = link['href']
                        carParkMetadata[carPark['meta']['name']] = {
                            'address': carPark['meta']['address'],
                            'postcode': carPark['meta']['address'].split(',')[-1].strip(),
                            'district': carPark['meta']['address'].split(',')[-1].strip().split(' ')[0],
                            'capacity': feed['meta']['totalSpaces'],
                            'latest': timeseries['latest']['value']
                        }

print('Discovered %u car parks with occupancy data.' % len(carParkTimeseriesIRIs))

carParkMetadata = pd.DataFrame.from_records(carParkMetadata).transpose()
carParkMetadata
# Out:
# Last updated 19 March 2020 09:57
# Discovered 28 car parks with occupancy data.
#                                                                             address  \
# BALTIC                                 BALTIC, South Shore Road, Gateshead, NE8 3BA
# Bank Foot Metro                   Bank Foot Metro Station, Station Road, Kenton ...
# Callerton Parkway Metro           Callerton Parkway Metro Station, Woolsington, ...
# Charles Street                                   Charles Street, Gateshead, NE8 1EW
# Church Street                                     Church Street, Gateshead, NE8 2AT
# Claremont Road                         Claremont Road, Newcastle upon Tyne, NE2 4AA
# Dean Street                               Dean Street, Newcastle upon Tyne, NE1 1PG
# East Boldon Metro                 East Boldon Metro Station, Station Road, East ...
# Eldon Garden                      Eldon Garden, Percy Street, Newcastle upon Tyn...
# Eldon Square                      Eldon Square, Percy Street, Newcastle upon Tyn...
# Ellison Place                           Ellison Place, Newcastle upon Tyne, NE1 8XS
# Fellgate Metro                    Fellgate Metro Station, Durham Drive, Fellgate...
# Four Lane Ends Interchange        Four Lane Ends Interchange, A188 Benton Lane, ...
# Gateshead Civic Centre            Gateshead Civic Centre, Arthur Street, Gateshe...
# Gateshead College                 Gateshead College, Quarryfield Road, Gateshead...
# Grainger Town                     Grainger Town, Waterloo Street, Newcastle upon...
# Heworth Interchange (Long Stay)      Low Heworth Lane, Heworth, Gateshead, NE10 0YJ
# Heworth Interchange (Short Stay)  Heworth Interchange, Shields Road, Heworth, Ga...
# Kingston Park Metro               Kingston Park Metro Station, Brunton Lane, Kin...
# Manors                            Manors, Trafalgar Street, Newcastle upon Tyne,...
# Mill Road                                             Mill Road, Gateshead, NE8 5JB
# Northumberland Park Metro         Northumberland Park Metro Station, Algernon Dr...
# Old Town Hall                        Old Town Hall, West Street, Gateshead, NE8 1DP
# Quarryfield Road                                   Abott's Hill, Gateshead, NE8 3DF
# Regent Centre Interchange         Regent Centre Interchange, B1318 Great North R...
# Sage Gateshead                    Sage Gateshead, Brandling Street, Gateshead, N...
# Stadium of Light Metro            Stadium of Light Metro Station, A1018 Newcastl...
# Swinburne Street                               Swinburne Street, Gateshead, NE8 1AX
#
#                                   postcode district capacity latest
# BALTIC                             NE8 3BA      NE8       71      1
# Bank Foot Metro                   NE13 8AG     NE13       62     13
# Callerton Parkway Metro           NE13 8DF     NE13      192      1
# Charles Street                     NE8 1EW      NE8       27      4
# Church Street                      NE8 2AT      NE8       43      9
# Claremont Road                     NE2 4AA      NE2      225     31
# Dean Street                        NE1 1PG      NE1      257    119
# East Boldon Metro                 NE36 0AB     NE36       75     51
# Eldon Garden                       NE1 7RT      NE1      449    155
# Eldon Square                       NE1 7RT      NE1      497    120
# Ellison Place                      NE1 8XS      NE1      126     47
# Fellgate Metro                    NE32 4QA     NE32       54     22
# Four Lane Ends Interchange        NE12 8LQ     NE12      475     81
# Gateshead Civic Centre             NE8 1HH      NE8      450    337
# Gateshead College                  NE8 3BE      NE8      226    167
# Grainger Town                      NE1 4DP      NE1      410     61
# Heworth Interchange (Long Stay)   NE10 0YJ     NE10      413     48
# Heworth Interchange (Short Stay)  NE10 0PA     NE10       64      3
# Kingston Park Metro                NE3 2SW      NE3       95      7
# Manors                             NE1 2LA      NE1      484    163
# Mill Road                          NE8 5JB      NE8      283    104
# Northumberland Park Metro         NE27 0SJ     NE27      405     52
# Old Town Hall                      NE8 1DP      NE8       53     10
# Quarryfield Road                   NE8 3DF      NE8      555      1
# Regent Centre Interchange          NE3 1HS      NE3      183     77
# Sage Gateshead                     NE8 3AE      NE8      285     74
# Stadium of Light Metro             SR5 1JB      SR5      182     40
# Swinburne Street                   NE8 1AX      NE8       57      6

# %%
daysPerRequest = 5

print('Requesting car park occupancy in %u day chunks...' % daysPerRequest)

dfCarParksBaseline = pd.read_pickle('cache/baseline-car-park-occupancy-pd.pkl')
# Out:
# Requesting car park occupancy in 5 day chunks...

# %%
dfCarParks = None

for carParkName in carParkTimeseriesIRIs.keys():
    carParkRequestTimeseries = carParkTimeseriesIRIs[carParkName]
    carParkTimeseries = []

    print('  %s' % carParkName)
    print('  [', end='')

    for windowStart in dateutil.rrule.rrule(
        dateutil.rrule.DAILY,
        interval=daysPerRequest,
        dtstart=baselineEnd + pd.Timedelta(seconds=1),
        until=dateToday + pd.Timedelta(hours=24)
    ):
        windowEnd = windowStart + pd.Timedelta(days=daysPerRequest) - pd.Timedelta(seconds=1)

        if windowEnd > dateToday + pd.Timedelta(hours=24):
            windowEnd = dateToday + pd.Timedelta(hours=24)
            
        windowResponse = json.loads(
            urllib.request.urlopen(
              '%s?startTime=%s&endTime=%s' % (carParkRequestTimeseries, windowStart.isoformat().replace('+00:00', 'Z'), windowEnd.isoformat().replace('+00:00', 'Z'))
            ).read().decode('utf-8')
        )['historic']['values']

        carParkTimeseries.extend(windowResponse)
        print('.', end='')

    print(']')

    # Duration isn't relevant to the car park data
    dfCP = pd.DataFrame.from_records(carParkTimeseries, exclude=['duration'])

    # Times in this API are in ISO8601
    dfCP['time'] = dfCP['time'].apply(lambda t: datetime.datetime.strptime(t, "%Y-%m-%dT%H:%M:%S.%fZ"))

    dfCP = dfCP.rename(columns={'value': carParkName})
    dfCP.set_index('time', inplace=True, drop=True)

    dfCP = dfCP.resample('%us' % resampleFrequency).median().fillna(method='ffill', limit=12)
    
    if dfCarParks is None:
        dfCarParks = dfCP
    else:
        dfCarParks = dfCarParks.join(dfCP, how='outer')
# Out:
#   BALTIC
#   [..]
#   Bank Foot Metro
#   [..]
#   Callerton Parkway Metro
#   [..]
#   Charles Street
#   [..]
#   Church Street
#   [..]
#   Claremont Road
#   [..]
#   Dean Street
#   [..]
#   East Boldon Metro
#   [..]
#   Eldon Garden
#   [..]
#   Eldon Square
#   [..]
#   Ellison Place
#   [..]
#   Fellgate Metro
#   [..]
#   Four Lane Ends Interchange
#   [..]
#   Gateshead Civic Centre
#   [..]
#   Gateshead College
#   [..]
#   Grainger Town
#   [..]
#   Heworth Interchange (Long Stay)
#   [..]
#   Heworth Interchange (Short Stay)
#   [..]
#   Kingston Park Metro
#   [..]
#   Manors
#   [..]
#   Mill Road
#   [..]
#   Northumberland Park Metro
#   [..]
#   Old Town Hall
#   [..]
#   Quarryfield Road
#   [..]
#   Regent Centre Interchange
#   [..]
#   Sage Gateshead
#   [..]
#   Stadium of Light Metro
#   [..]
#   Swinburne Street
#   [..]

# %%
dfCarParks = pd.concat([dfCarParksBaseline, dfCarParks]).sort_index()
dfCarParks
# Out:
#                      BALTIC  Bank Foot Metro  Callerton Parkway Metro  \
# time
# 2019-03-15 00:00:00     0.0              0.0                      0.0
# 2019-03-15 00:15:00     0.0              0.0                      0.0
# 2019-03-15 00:30:00     0.0              0.0                      0.0
# 2019-03-15 00:45:00     0.0              0.0                      1.0
# 2019-03-15 01:00:00     0.0              0.0                      1.0
# ...                     ...              ...                      ...
# 2020-03-19 08:45:00     9.0             13.5                      5.0
# 2020-03-19 09:00:00     9.0             13.0                      4.0
# 2020-03-19 09:15:00     9.0             13.0                      4.0
# 2020-03-19 09:30:00     0.0             14.0                      3.0
# 2020-03-19 09:45:00     2.0             14.0                      2.0
#
#                      Charles Street  Church Street  Claremont Road  \
# time
# 2019-03-15 00:00:00             0.0            0.0             NaN
# 2019-03-15 00:15:00             0.0            0.0             NaN
# 2019-03-15 00:30:00             0.0            0.0             NaN
# 2019-03-15 00:45:00             0.0            0.0             NaN
# 2019-03-15 01:00:00             0.0            0.0             NaN
# ...                             ...            ...             ...
# 2020-03-19 08:45:00             1.5            7.0            24.0
# 2020-03-19 09:00:00             1.5            7.0            30.0
# 2020-03-19 09:15:00             0.0            7.0            30.0
# 2020-03-19 09:30:00             0.0            7.0            31.0
# 2020-03-19 09:45:00             4.0            9.0            33.0
#
#                      Dean Street  East Boldon Metro  Eldon Garden  \
# time
# 2019-03-15 00:00:00          NaN               21.0           NaN
